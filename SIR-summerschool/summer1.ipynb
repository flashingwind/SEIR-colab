# %% [markdown]
# ## I. Pythonとプログラミングの基礎(1)——変数，関数，型
#
# ### 今日のテーマ
#
# - Pythonと多くの(手続き型言語)はだいたい同じ機能を持っている
# - そのためプログラミング経験者があると，他の言語も早く習得できることがある
# - そのような*プログラミング言語の基本的な機能*を覚え，それらを適切に組み合わせられるようになる
#
# ### 言語の基本機能
#
# - 演算
# - データとデータ型(データには型がある)
#   - 基本の型(int，float，str，bool)
#   - コレクション型(list，dict，tuple)
#   - クラスとインスタンス化……オブジェクト指向
#   - ベクトル・行列または配列
# - 変数(データなどを入れる)
# - くり返し(for-in，for-in-range)
# - 関数(メソッド)
# - クラス
# - 行列，ベクトル，`import numpy as np`
#
# ※約3回でこれらをやる予定
#
# ### 変数・演算

# %%
b=1
b=2
a=b-2
print('a=',a)
print('type(a)=',type(a))
print('type(2)=',type(1),type(1.2),type(a))
c='a'
print(type("c"),type(c))

if(type(a) is str):
    print("True")
else:
    print("TypeError")
# Out:
# a= 0
# type(a)= <class 'int'>
# type(2)= <class 'int'> <class 'float'> <class 'int'>
# <class 'str'> <class 'str'>
# TypeError

# %% [markdown]
# - 加減乗除は常識的な書き方で大丈夫
# - イコール(=)は，右辺の計算結果を左辺の変数に上書き保存する．数学的なイコールとはちがう
#   - なので，原則的に左辺は変数1個
#
# ### 演習
#
# 1. 自分で作った変数の型を表示しなさい

# %%
# 自分で作った変数の型を表示しなさい

# %% [markdown]
# ### 関数
#
#   - 手続きをいい感じの単位でまとめたもの．def ……(……):は関数定義を示す特別なワード
#   - aは引数を表し，関数を呼び出すときに指定する
#   - 関数は値を返すことがある: `return`で明示する
#
#   - 関数を使うときはカッコを付けて`……(……)`で呼び出す
#   - ※`print("abc")`も関数

# %%
def add_one(a):
    
    return a+1

# %%
a=add_one(3)
print(a)

print(add_one(4)*2)
# Out:
# 4
# 10
