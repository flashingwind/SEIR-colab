# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()

#アップロードするファイルを選択

df = pd.read_csv('')
# Out:
#      <input type="file" id="files-ab23a236-711b-4c7e-aa66-5eb0a46db53a" name="files[]" multiple disabled />
#      <output id="result-ab23a236-711b-4c7e-aa66-5eb0a46db53a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-60b10d40c62d> in <module>()
#       2 import pandas as pd
#       3 from google.colab import files
# ----> 4 uploaded = files.upload()
#       5
#       6 #アップロードするファイルを選択
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ...

# %%
# !ls /content/sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
#認証が必要
import pandas as pd
from google.colab import drive
drive.mount('/content/drive/')

#google driveのMy Drive内にあるinput.csvを選択
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/gis/tblT000876Q5540.txt')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,5,6,28,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# !ls /content/drive/My\ Drive/Colab\ Notebooks/gis/tblT000876Q5540.txt
# Out:
# '/content/drive/My Drive/Colab Notebooks/gis/tblT000876Q5540.txt'

# %%
print(df["KEY_CODE"])
print(df["GASSAN"])
# Out:
# 0                 NaN
# 1        5.540000e+09
# 2        5.540000e+09
# 3        5.540000e+09
# 4        5.540000e+09
#              ...
# 25158    5.540777e+09
# 25159    5.540777e+09
# 25160    5.540778e+09
# 25161    5.540778e+09
# 25162    5.540779e+09
# Name: KEY_CODE, Length: 25163, dtype: float64
# 0               NaN
# 1               NaN
# 2        5540000011
# 3               NaN
# 4               NaN
#             ...
# 25158           NaN
# 25159           NaN
# 25160           NaN
# 25161           NaN
# 25162           NaN
# Name: GASSAN, Length: 25163, dtype: object
